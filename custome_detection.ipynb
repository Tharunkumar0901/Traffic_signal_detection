# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/yolov3/ts'
# Out:
# 00000.jpg  00189.txt  00400.jpg  00662.txt
# 00000.txt  00190.jpg  00400.txt  00663.jpg
# 00001.jpg  00190.txt  00401.jpg  00663.txt
# 00001.txt  00191.jpg  00401.txt  00664.jpg
# 00002.jpg  00191.txt  00402.jpg  00664.txt
# 00002.txt  00192.jpg  00402.txt  00665.jpg
# 00003.jpg  00192.txt  00403.jpg  00665.txt
# 00003.txt  00193.jpg  00403.txt  00667.jpg
# 00004.jpg  00193.txt  00404.jpg  00667.txt
# 00004.txt  00194.jpg  00404.txt  00668.jpg
# 00005.jpg  00194.txt  00405.jpg  00668.txt
# 00005.txt  00195.jpg  00405.txt  00669.jpg
# 00006.jpg  00195.txt  00406.jpg  00669.txt
# 00006.txt  00196.jpg  00406.txt  00670.jpg
# 00007.jpg  00196.txt  00408.jpg  00670.txt
# 00007.txt  00197.jpg  00408.txt  00671.jpg
# 00008.jpg  00197.txt  00410.jpg  00671.txt
# 00008.txt  00198.jpg  00410.txt  00672.jpg
# 00009.jpg  00198.txt  00411.jpg  00672.txt
# 00009.txt  00199.jpg  00411.txt  00673.jpg
# 00010.jpg  00199.txt  00412.jpg  00673.txt
# 00010.txt  00200.jpg  00412.txt  00674.jpg
# ...

# %%
# !unzip '/content/drive/MyDrive/yolov3/ts/ts.zip' -d '/content/drive/MyDrive/yolov3'
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/yolov3/ts/ts.zip, /content/drive/MyDrive/yolov3/ts/ts.zip.zip or /content/drive/MyDrive/yolov3/ts/ts.zip.ZIP.

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/yolov3/d'
# Out:
# Cloning into '/content/drive/MyDrive/yolov3/d'...
# remote: Enumerating objects: 15530, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15530 (delta 6), reused 10 (delta 4), pack-reused 15514
# Receiving objects: 100% (15530/15530), 14.21 MiB | 7.60 MiB/s, done.
# Resolving deltas: 100% (10418/10418), done.
# Updating files: 100% (2058/2058), done.

# %%
# %cd  '/content/drive/MyDrive/yolov3/darknet'
# Out:
# /content/drive/MyDrive/yolov3/darknet

# %%
# %cd '/content/drive/MyDrive/yolov3/darknet'
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/g' Makefile
# !sed -i "s/ARCH= -gencode arch=compute_60,code=sm_60/ARCH= ${ARCH_VALUE}/g" Makefile
# !make
# Out:
# /content/drive/MyDrive/yolov3/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# %cd '/content/drive/MyDrive/yolov3'
# Out:
# /content/drive/MyDrive/yolov3

# %%
# !python ts/creating-files-data-and-name.py
# !python ts/creating-train-and-test-txt-files.py

# %%
# !python ts/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# !darknet/darknet detector train ts/labelled_data.data darknet/cfg/yolov3_ts_train.cfg weight/darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 11080 (12000), cuDNN: 8.9.0, GPU count: 1
#  OpenCV version: 4.5.4
# yolov3_ts_train
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 2, batch = 32, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
